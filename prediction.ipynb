# %%
import pandas as pd

# %%
data = pd.read_csv("Laptop_price.csv")

# %%
data
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 0      Asus         3.830296        16               512    11.185147
# 1      Acer         2.912833         4              1000    11.311372
# 2    Lenovo         3.241627         4               256    11.853023
# 3      Acer         3.806248        16               512    12.280360
# 4      Acer         3.268097        32              1000    14.990877
# ..      ...              ...       ...               ...          ...
# 995      HP         3.343584         4              1000    12.587095
# 996    Dell         2.780555         8               256    12.679356
# 997    Dell         3.200569         4               512    12.666315
# 998    Asus         1.604182         8               256    11.215581
# 999  Lenovo         1.711980         4               256    16.561498
#
#        Weight         Price
# 0    2.641094  17395.093065
# 1    3.260012  31607.605919
# 2    2.029061   9291.023542
# 3    4.573865  17436.728334
# 4    4.193472  32917.990718
# ..        ...           ...
# 995  3.162399  31593.668017
# 996  3.750265   9149.521832
# 997  3.392612  16552.404779
# 998  3.857613   9407.473459
# 999  3.440883   8807.696702
#
# [1000 rows x 7 columns]

# %%
data.isna().sum()
# Out:
# Brand               0
# Processor_Speed     0
# RAM_Size            0
# Storage_Capacity    0
# Screen_Size         0
# Weight              0
# Price               0
# dtype: int64

# %%
data.head(10)
# Out:
#     Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight  \
# 0    Asus         3.830296        16               512    11.185147  2.641094
# 1    Acer         2.912833         4              1000    11.311372  3.260012
# 2  Lenovo         3.241627         4               256    11.853023  2.029061
# 3    Acer         3.806248        16               512    12.280360  4.573865
# 4    Acer         3.268097        32              1000    14.990877  4.193472
# 5      HP         1.881348        16               256    11.943958  4.840268
# 6  Lenovo         2.940721        32               256    11.713246  4.344846
# 7  Lenovo         3.016788         4               256    15.588315  2.941120
# 8  Lenovo         2.560327         4               512    15.026332  2.743620
# 9    Acer         3.341111        32               512    13.611945  4.093149
#
#           Price
# 0  17395.093065
# 1  31607.605919
# 2   9291.023542
# 3  17436.728334
# 4  32917.990718
# 5   9543.719980
# 6  10390.137319
# 7   9214.484506
# 8  16372.175284
# 9  18501.832733

# %%
data.describe()
# Out:
#        Processor_Speed     RAM_Size  Storage_Capacity  Screen_Size  \
# count      1000.000000  1000.000000       1000.000000  1000.000000
# mean          2.750611    15.500000        584.576000    14.056790
# std           0.731796    10.988665        313.438517     1.705882
# min           1.511580     4.000000        256.000000    11.012111
# 25%           2.089246     8.000000        256.000000    12.635523
# 50%           2.760885    16.000000        512.000000    14.099643
# 75%           3.362610    32.000000       1000.000000    15.528590
# max           3.998534    32.000000       1000.000000    16.985737
#
#             Weight         Price
# count  1000.000000   1000.000000
# mean      3.466919  19604.187963
# std       0.866541   9406.064880
# min       2.000560   8570.012950
# 25%       2.717211  10114.012948
# 50%       3.464630  17287.241878
# 75%       4.212583  31566.214754
# max       4.990728  33503.935037

# %%
numeric_data = data.select_dtypes(include=["number"])

# %%
numeric_data.corr()
# Out:
#                   Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# Processor_Speed          1.000000  0.021391         -0.067576    -0.013425
# RAM_Size                 0.021391  1.000000          0.002111    -0.036002
# Storage_Capacity        -0.067576  0.002111          1.000000    -0.027560
# Screen_Size             -0.013425 -0.036002         -0.027560     1.000000
# Weight                  -0.054603 -0.025382          0.041335     0.021995
# Price                   -0.050737  0.061237          0.997908    -0.026740
#
#                     Weight     Price
# Processor_Speed  -0.054603 -0.050737
# RAM_Size         -0.025382  0.061237
# Storage_Capacity  0.041335  0.997908
# Screen_Size       0.021995 -0.026740
# Weight            1.000000  0.038417
# Price             0.038417  1.000000

# %%
import matplotlib

data.groupby("Brand")["Price"].mean().sort_values(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='Brand'>

# %%
data.groupby("RAM_Size")["Brand"].value_counts().reset_index()
# Out:
#     RAM_Size   Brand  count
# 0          4      HP     59
# 1          4    Acer     50
# 2          4    Dell     48
# 3          4    Asus     47
# 4          4  Lenovo     39
# 5          8    Asus     66
# 6          8  Lenovo     51
# 7          8    Acer     48
# 8          8    Dell     43
# 9          8      HP     38
# 10        16    Dell     52
# 11        16      HP     49
# 12        16    Acer     47
# 13        16    Asus     47
# 14        16  Lenovo     42
# 15        32    Dell     67
# 16        32    Acer     59
# 17        32  Lenovo     58
# 18        32    Asus     46
# 19        32      HP     44

# %%
data["Brand"].value_counts().sort_values(ascending=False).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
data["Brand"].value_counts()
# Out:
# Brand
# Dell      210
# Asus      206
# Acer      204
# Lenovo    190
# HP        190
# Name: count, dtype: int64

# %%
y = data["Price"]
X = data[["Processor_Speed","RAM_Size","Storage_Capacity"]]

# %%
X
# Out:
#      Processor_Speed  RAM_Size  Storage_Capacity
# 0           3.830296        16               512
# 1           2.912833         4              1000
# 2           3.241627         4               256
# 3           3.806248        16               512
# 4           3.268097        32              1000
# ..               ...       ...               ...
# 995         3.343584         4              1000
# 996         2.780555         8               256
# 997         3.200569         4               512
# 998         1.604182         8               256
# 999         1.711980         4               256
#
# [1000 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfmodel = RandomForestRegressor()

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_gridfr = {
    "max_depth":[2,5,10,15,20,25],
    "max_features":["auto","log2"],
    "n_estimators":[2,4,6,8,10,12],
    
}

# %%
grid = GridSearchCV(rfmodel,param_grid=param_gridfr)

# %%
grid.fit(X_train,y_train)
# Out:
# c:\Users\admin\anaconda3\envs\MLP\Lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 180 fits failed out of a total of 360.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\admin\anaconda3\envs\MLP\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\admin\anaconda3\envs\MLP\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#   File "c:\Users\admin\anaconda3\envs\MLP\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\admin\anaconda3\envs\MLP\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\admin\anaconda3\envs\MLP\Lib\site-packages\sklearn\model_selection\_search.py:1135: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#  0.51539246 0.53109347 0.6865296  0.61811511 0.6865868  0.73817821
#         nan        nan        nan        nan        nan        nan
#  0.88382433 0.90913126 0.94151435 0.95792924 0.97502385 0.96865265
#         nan        nan        nan        nan        nan        nan
#  0.97850259 0.98500667 0.98792724 0.98485758 0.99006158 0.9930956
#         nan        nan        nan        nan        nan        nan
#  0.95150613 0.98677056 0.98658048 0.99014201 0.99248529 0.99165453
#         nan        nan        nan        nan        nan        nan
#  0.9668594  0.98514708 0.99188044 0.99132993 0.99011629 0.9931086
#         nan        nan        nan        nan        nan        nan
#  0.98283202 0.98276519 0.98092415 0.99185726 0.99064441 0.9924308 ]
#   warnings.warn(
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [2, 5, 10, 15, 20, 25],
#                          'max_features': ['auto', 'log2'],
#                          'n_estimators': [2, 4, 6, 8, 10, 12]})

# %%
grid.best_params_
# Out:
# {'max_depth': 20, 'max_features': 'log2', 'n_estimators': 12}

# %%
predictions = grid.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 458.23282775053156

# %%
data["Price"].describe()
# Out:
# count     1000.000000
# mean     19604.187963
# std       9406.064880
# min       8570.012950
# 25%      10114.012948
# 50%      17287.241878
# 75%      31566.214754
# max      33503.935037
# Name: Price, dtype: float64

# %%
grid
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [2, 5, 10, 15, 20, 25],
#                          'max_features': ['auto', 'log2'],
#                          'n_estimators': [2, 4, 6, 8, 10, 12]})

# %%
import joblib
joblib.dump(grid,"rf_model.pkl")
# Out:
# ['rf_model.pkl']
